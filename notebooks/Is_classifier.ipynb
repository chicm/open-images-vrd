# %%
import os
import numpy as np
import pandas as pd
import torch
import os
import json
import pandas as pd
from PIL import Image
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import cv2
import numpy as np
# %matplotlib inline
from tqdm import tqdm
import glob
import pickle
import glob
import os.path as osp
DATA_DIR = '/mnt/chicm/data/open-images/relation'
DETECT_DATA_DIR = '/mnt/chicm/data/open-images/detect'
IMG_DIR = '/mnt/chicm/data/open-images/train/imgs'

# %%
img_files = glob.glob(IMG_DIR + '/**/*.jpg')
fullpath_dict = {}
for fn in img_files:
    fullpath_dict[osp.basename(fn).split('.')[0]] = fn

# %%
fullpath_dict['780d8a470d144fa0']
# Out:
# 'train_7/780d8a470d144fa0.jpg'

# %%
# !ls $DATA_DIR
# Out:
# challenge-2019-attributes-description.csv
# challenge-2019-classes-vrd.csv
# challenge-2019-relationships-description.csv
# challenge-2019-relationship-triplets.csv
# challenge-2019-train-vrd-bbox.csv
# challenge-2019-train-vrd.csv
# challenge-2019-train-vrd-labels.csv
# challenge-2019-validation-vrd-bbox.csv
# challenge-2019-validation-vrd.csv
# challenge-2019-validation-vrd-labels.csv
# top_classes.csv
# VRD_sample_submission.csv

# %%
df_box = pd.read_csv(os.path.join(DATA_DIR, 'challenge-2019-train-vrd-bbox.csv'), dtype={'XMin':str, 'XMax':str, 'YMin': str, 'YMax': str})
df_box.head()
# Out:
#             ImageID LabelName      XMin      XMax      YMin      YMax  \
# 0  780d8a470d144fa0  /m/04yx4  0.000000  0.527143  0.029979  0.997859
# 1  780d8a470d144fa0  /m/04yx4  0.291429  0.687143  0.128480  0.997859
# 2  780d8a470d144fa0  /m/04yx4  0.590000  0.965714  0.164882  0.997859
# 3  780db0a7d07a4a20  /m/026t6  0.000000  1.000000  0.345625  0.990000
# 4  780db0a7d07a4a20  /m/026t6  0.271667  0.626667  0.803125  0.999375
#
#    IsGroupOf
# 0          0
# 1          0
# 2          0
# 3         -1
# 4          0

# %%
x = df_box.ImageID + '_' + df_box.LabelName + '_' + df_box.XMin
x
# Out:
# 0            780d8a470d144fa0_/m/04yx4_0.000000
# 1            780d8a470d144fa0_/m/04yx4_0.291429
# 2            780d8a470d144fa0_/m/04yx4_0.590000
# 3            780db0a7d07a4a20_/m/026t6_0.000000
# 4            780db0a7d07a4a20_/m/026t6_0.271667
# 5            780db0a7d07a4a20_/m/026t6_0.562500
# 6            780db0a7d07a4a20_/m/026t6_0.645000
# 7            780db0a7d07a4a20_/m/0hg7b_0.266667
# 8            780db0a7d07a4a20_/m/0hg7b_0.500000
# 9            780db1d52d5aee6c_/m/04yx4_0.441250
# 10           780dc0ff229f14f1_/m/04yx4_0.722500
# 11         780dc0ff229f14f1_/m/0bwd_0j_0.506250
# 12         780dc0ff229f14f1_/m/0bwd_0j_0.107500
# 13         780dc0ff229f14f1_/m/0bwd_0j_0.209375
# 14         780dc0ff229f14f1_/m/0bwd_0j_0.392500
# 15           780ddae87e5cd792_/m/04yx4_0.000000
# 16           780ddae87e5cd792_/m/04yx4_0.047842
# 17            780df154f3f66fc2_/m/0k4j_0.000000
# 18            780df154f3f66fc2_/m/0k4j_0.000000
# 19         780df7cd6a682fd9_/m/03bt1vf_0.000000
# 20         780df7cd6a682fd9_/m/03bt1vf_0.000000
# 21         780df7cd6a682fd9_/m/03bt1vf_0.523125
# 22         780df7cd6a682fd9_/m/03bt1vf_0.569375
# 23           780df7cd6a682fd9_/m/04yx4_0.000000
# 24           780df7cd6a682fd9_/m/04yx4_0.000000
# 25           780df7cd6a682fd9_/m/04yx4_0.119375
# 26           780df7cd6a682fd9_/m/04yx4_0.130000
# 27           780df7cd6a682fd9_/m/04yx4_0.346875
# 28           780df7cd6a682fd9_/m/04yx4_0.351875
# 29           780df7cd6a682fd9_/m/04yx4_0.385000
#                            ...
# 3290040    4fef4314cba2568a_/m/03bt1vf_0.106875
# 3290041    4fef4314cba2568a_/m/03bt1vf_0.133125
# 3290042    4fef4314cba2568a_/m/03bt1vf_0.443750
# 3290043      4fef4314cba2568a_/m/04yx4_0.000000
# 3290044      4fef4314cba2568a_/m/04yx4_0.205625
# 3290045      4fef4314cba2568a_/m/04yx4_0.408750
# 3290046      4fef4314cba2568a_/m/04yx4_0.447500
# 3290047      4fef4314cba2568a_/m/04yx4_0.451250
# 3290048      4fef4314cba2568a_/m/04yx4_0.512500
# 3290049    4fef4a75f4cf746b_/m/03bt1vf_0.345000
# 3290050    4fef4a75f4cf746b_/m/03bt1vf_0.490000
# 3290051     4fef587ec96bb9de_/m/04bcr3_0.000000
# 3290052      4fef838156a0c0ab_/m/0199g_0.263125
# 3290053    4fef85d8292c45e6_/m/04dr76w_0.000000
# 3290054      4fef85d8292c45e6_/m/04yx4_0.168750
# 3290055    4fef85d8292c45e6_/m/04dr76w_0.057813
# 3290056    4fef85d8292c45e6_/m/04dr76w_0.139062
# 3290057    4fef85d8292c45e6_/m/04dr76w_0.784375
# 3290058    4fef85d8292c45e6_/m/04dr76w_0.854688
# 3290059    4fef85d8292c45e6_/m/04dr76w_0.859375
# 3290060    4fef85d8292c45e6_/m/04dr76w_0.946875
# 3290061    4fef85d8292c45e6_/m/04dr76w_0.982813
# 3290062      4fef85d8292c45e6_/m/04yx4_0.000000
# 3290063      4fef85d8292c45e6_/m/04yx4_0.042188
# 3290064      4fef85d8292c45e6_/m/04yx4_0.359375
# 3290065      4fef85d8292c45e6_/m/04yx4_0.420312
# 3290066      4fef85d8292c45e6_/m/04yx4_0.584375
# 3290067      4fef85d8292c45e6_/m/04yx4_0.800000
# 3290068      4fef85d8292c45e6_/m/04yx4_0.846875
# 3290069      4fef85d8292c45e6_/m/04yx4_0.903125
# Length: 3290070, dtype: object

# %%
df_vrd = pd.read_csv(os.path.join(DATA_DIR, 'challenge-2019-train-vrd.csv'), converters={
    'XMin1':lambda x: '{:.6f}'.format(float(x)),
    'XMax1':lambda x: '{:.6f}'.format(float(x)),
    'YMin1':lambda x: '{:.6f}'.format(float(x)),
    'YMax1':lambda x: '{:.6f}'.format(float(x))})
df_vrd.head()
# Out:
#             ImageID  LabelName1 LabelName2     XMin1     XMax1     YMin1  \
# 0  fe58ec1b06db2bb7   /m/04bcr3   /m/083vt  0.005000  0.033125  0.580000
# 1  82d16a22f703df5c  /m/04dr76w  /m/02gy9n  0.612000  0.735000  0.418919
# 2  b54d41beabcfd900   /m/01mzpv   /m/083vt  0.372500  0.399375  0.706413
# 3  4b6a08cc110d7275   /m/01mzpv  /m/01y9k5  0.171250  0.255625  0.557500
# 4  0144cfbb726f4c72   /m/01mzpv  /m/04bcr3  0.855000  0.950000  0.561667
#
#       YMax1    XMin2     XMax2     YMin2     YMax2 RelationshipLabel
# 0  0.627778  0.00500  0.033125  0.580000  0.627778                is
# 1  0.950450  0.61200  0.735000  0.418919  0.950450                is
# 2  0.778557  0.37250  0.399375  0.706413  0.778557                is
# 3  0.749167  0.20750  0.683125  0.611667  0.999167                at
# 4  0.609167  0.82875  0.999375  0.568333  0.673333                at

# %%
df_vrd.loc[df_vrd.ImageID=='fe58ec1b06db2bb7']
# Out:
#                  ImageID LabelName1 LabelName2     XMin1     XMax1  \
# 0       fe58ec1b06db2bb7  /m/04bcr3   /m/083vt     0.005  0.033125
# 77712   fe58ec1b06db2bb7  /m/04bcr3   /m/083vt  0.071875  0.121875
# 171028  fe58ec1b06db2bb7  /m/04bcr3   /m/083vt  0.124375    0.2175
# 230777  fe58ec1b06db2bb7  /m/04bcr3   /m/083vt     0.185  0.308125
# 284575  fe58ec1b06db2bb7  /m/04bcr3   /m/083vt   0.51375  0.903125
# 362652  fe58ec1b06db2bb7  /m/04bcr3   /m/083vt   0.30875    0.5175
# 370350  fe58ec1b06db2bb7  /m/04bcr3   /m/083vt  0.038125  0.071875
#
#              YMin1       YMax1     XMin2     XMax2     YMin2     YMax2  \
# 0             0.58  0.62777776  0.005000  0.033125  0.580000  0.627778
# 77712    0.5977778        0.68  0.071875  0.121875  0.597778  0.680000
# 171028   0.6122222   0.7122222  0.124375  0.217500  0.612222  0.712222
# 230777   0.5933333   0.7688889  0.185000  0.308125  0.593333  0.768889
# 284575        0.68   0.9988889  0.513750  0.903125  0.680000  0.998889
# 362652  0.63222224  0.86444443  0.308750  0.517500  0.632222  0.864444
# 370350   0.5822222   0.6622222  0.038125  0.071875  0.582222  0.662222
#
#        RelationshipLabel
# 0                     is
# 77712                 is
# 171028                is
# 230777                is
# 284575                is
# 362652                is
# 370350                is

# %%
df_box.loc[df_box.ImageID=='fe58ec1b06db2bb7']
# Out:
#                   ImageID  LabelName      XMin      XMax      YMin      YMax  \
# 2055608  fe58ec1b06db2bb7  /m/04bcr3  0.185000  0.308125  0.593333  0.768889
# 2055609  fe58ec1b06db2bb7  /m/04bcr3  0.005000  0.033125  0.580000  0.627778
# 2055610  fe58ec1b06db2bb7  /m/04bcr3  0.038125  0.071875  0.582222  0.662222
# 2055611  fe58ec1b06db2bb7  /m/04bcr3  0.071875  0.121875  0.597778  0.680000
# 2055612  fe58ec1b06db2bb7  /m/04bcr3  0.124375  0.217500  0.612222  0.712222
# 2055613  fe58ec1b06db2bb7  /m/04bcr3  0.308750  0.517500  0.632222  0.864444
# 2055614  fe58ec1b06db2bb7  /m/04bcr3  0.513750  0.903125  0.680000  0.998889
#
#          IsGroupOf
# 2055608          0
# 2055609          0
# 2055610          0
# 2055611          0
# 2055612          0
# 2055613          0
# 2055614          0

# %%
df_vrd.shape
# Out:
# (374768, 12)

# %%
df_vrd.loc[df_vrd.RelationshipLabel=='is'].shape
# Out:
# (194142, 12)

# %%
print(df_vrd.shape, len(df_vrd.ImageID.unique()), len(df_vrd.LabelName1.unique()),\
      len(df_vrd.LabelName2.unique()), len(df_vrd.RelationshipLabel.unique()))
# Out:
# (374768, 12) 100522 32 58 10

# %%
df_classes = pd.read_csv(osp.join(DATA_DIR, 'challenge-2019-classes-vrd.csv'), names=['classes', 'desc'])
df_classes.head()
# Out:
#     classes        desc
# 0  /m/05r5c       Piano
# 1  /m/01599        Beer
# 2  /m/01_5g  Chopsticks
# 3  /m/01yrx         Cat
# 4  /m/04_sv  Motorcycle

# %%
df_att = pd.read_csv(osp.join(DATA_DIR, 'challenge-2019-attributes-description.csv'), names=['classes', 'desc'])
df_att.head()
# Out:
#      classes              desc
# 0  /m/02gy9n       Transparent
# 1   /m/05z87           Plastic
# 2   /m/0dnr7  (made of)Textile
# 3   /m/04lbp  (made of)Leather
# 4   /m/083vt            Wooden

# %%
def get_class_name(label):
    return df_classes.loc[df_classes.classes==label].desc.values[0]

def get_att_name(label):
    return df_att.loc[df_att.classes==label].desc.values[0]

# %%
def show_is_relation(idx):
    row = df_vrd.loc[df_vrd.RelationshipLabel=='is'].iloc[idx]
    fn = fullpath_dict[row.ImageID]
    #img = Image.open(fn)
    img = cv2.cvtColor(cv2.imread(fn), cv2.COLOR_BGR2RGB)
    print(img.shape)
    h, w, _ = img.shape
    x1, x2, y1, y2 = int(row.XMin1*w), int(row.XMax1*w), int(row.YMin1*h), int(row.YMax1*h)
    crop_img = img[y1:y2, x1:x2, :]
    
    print(get_class_name(row.LabelName1), get_att_name(row.LabelName2))
    
    #crop_img = cv2.resize(crop_img, (224, 224))
    
    plt.figure(figsize=(20, 10))
    plt.subplot(121)
    plt.imshow(img)
    plt.subplot(122)
    plt.imshow(crop_img)

# %%
show_is_relation(2005)
# Out:
# (683, 1024, 3)
# Guitar Wooden

# %%
df_vrd.loc[df_vrd.ImageID=='fe58ec1b06db2bb7']
# Out:
#                  ImageID LabelName1 LabelName2     XMin1     XMax1     YMin1  \
# 0       fe58ec1b06db2bb7  /m/04bcr3   /m/083vt  0.005000  0.033125  0.580000
# 77712   fe58ec1b06db2bb7  /m/04bcr3   /m/083vt  0.071875  0.121875  0.597778
# 171028  fe58ec1b06db2bb7  /m/04bcr3   /m/083vt  0.124375  0.217500  0.612222
# 230777  fe58ec1b06db2bb7  /m/04bcr3   /m/083vt  0.185000  0.308125  0.593333
# 284575  fe58ec1b06db2bb7  /m/04bcr3   /m/083vt  0.513750  0.903125  0.680000
# 362652  fe58ec1b06db2bb7  /m/04bcr3   /m/083vt  0.308750  0.517500  0.632222
# 370350  fe58ec1b06db2bb7  /m/04bcr3   /m/083vt  0.038125  0.071875  0.582222
#
#            YMax1     XMin2     XMax2     YMin2     YMax2 RelationshipLabel
# 0       0.627778  0.005000  0.033125  0.580000  0.627778                is
# 77712   0.680000  0.071875  0.121875  0.597778  0.680000                is
# 171028  0.712222  0.124375  0.217500  0.612222  0.712222                is
# 230777  0.768889  0.185000  0.308125  0.593333  0.768889                is
# 284575  0.998889  0.513750  0.903125  0.680000  0.998889                is
# 362652  0.864444  0.308750  0.517500  0.632222  0.864444                is
# 370350  0.662222  0.038125  0.071875  0.582222  0.662222                is

# %%
df_vrd['labels'] = df_vrd.LabelName1.str.cat(df_vrd.LabelName2, sep=' ')
df_vrd.head()
# Out:
#             ImageID  LabelName1 LabelName2    XMin1     XMax1     YMin1  \
# 0  fe58ec1b06db2bb7   /m/04bcr3   /m/083vt  0.00500  0.033125  0.580000
# 1  82d16a22f703df5c  /m/04dr76w  /m/02gy9n  0.61200  0.735000  0.418919
# 2  b54d41beabcfd900   /m/01mzpv   /m/083vt  0.37250  0.399375  0.706413
# 3  4b6a08cc110d7275   /m/01mzpv  /m/01y9k5  0.17125  0.255625  0.557500
# 4  0144cfbb726f4c72   /m/01mzpv  /m/04bcr3  0.85500  0.950000  0.561667
#
#       YMax1    XMin2     XMax2     YMin2     YMax2 RelationshipLabel  \
# 0  0.627778  0.00500  0.033125  0.580000  0.627778                is
# 1  0.950450  0.61200  0.735000  0.418919  0.950450                is
# 2  0.778557  0.37250  0.399375  0.706413  0.778557                is
# 3  0.749167  0.20750  0.683125  0.611667  0.999167                at
# 4  0.609167  0.82875  0.999375  0.568333  0.673333                at
#
#                  labels
# 0    /m/04bcr3 /m/083vt
# 1  /m/04dr76w /m/02gy9n
# 2    /m/01mzpv /m/083vt
# 3   /m/01mzpv /m/01y9k5
# 4   /m/01mzpv /m/04bcr3

# %%
len(df_vrd.loc[df_vrd.RelationshipLabel=='is'].labels.unique())
# Out:
# 42

# %%
df_vrd.loc[df_vrd.RelationshipLabel=='is'].labels.value_counts()
# Out:
# /m/04bcr3 /m/083vt      43161
# /m/01mzpv /m/083vt      36632
# /m/01mzpv /m/05z87      21875
# /m/04dr76w /m/02gy9n    19356
# /m/0342h /m/083vt       13444
# /m/01mzpv /m/04lbp      11949
# /m/04dr76w /m/05z87      7914
# /m/01y9k5 /m/083vt       7472
# /m/0cvnqh /m/083vt       5037
# /m/04bcr3 /m/05z87       4981
# /m/078n6m /m/083vt       3053
# /m/026t6 /m/083vt        2906
# /m/07y_7 /m/083vt        2550
# /m/080hkjn /m/0dnr7      2395
# /m/03m3pdh /m/0dnr7      1494
# /m/080hkjn /m/04lbp      1425
# /m/03ssj5 /m/083vt       1370
# /m/01940j /m/0dnr7       1205
# /m/04bcr3 /m/02gy9n       833
# /m/05r5c /m/083vt         822
# /m/03m3pdh /m/04lbp       635
# /m/01s55n /m/0dnr7        535
# /m/01_5g /m/083vt         509
# /m/05r5c /m/05z87         360
# /m/078n6m /m/02gy9n       335
# /m/078n6m /m/05z87        308
# /m/071p9 /m/083vt         204
# /m/01s55n /m/04lbp        194
# /m/0584n8 /m/0dnr7        153
# /m/0cmx8 /m/05z87         151
# /m/01s55n /m/05z87        138
# /m/0584n8 /m/04lbp        137
# /m/02p5f1q /m/05z87       133
# /m/02jvh9 /m/05z87         78
# /m/01940j /m/04lbp         71
# /m/01_5g /m/05z87          65
# /m/02p5f1q /m/02gy9n       62
# /m/02jvh9 /m/02gy9n        58
# /m/0dt3t /m/05z87          55
# /m/0cvnqh /m/05z87         52
# /m/04ctx /m/05z87          30
# /m/02jvh9 /m/083vt          5
# Name: labels, dtype: int64

# %%
df_box.loc[df_box.ImageID=='fe58ec1b06db2bb7']
# Out:
#                   ImageID  LabelName      XMin      XMax      YMin      YMax  \
# 2055608  fe58ec1b06db2bb7  /m/04bcr3  0.185000  0.308125  0.593333  0.768889
# 2055609  fe58ec1b06db2bb7  /m/04bcr3  0.005000  0.033125  0.580000  0.627778
# 2055610  fe58ec1b06db2bb7  /m/04bcr3  0.038125  0.071875  0.582222  0.662222
# 2055611  fe58ec1b06db2bb7  /m/04bcr3  0.071875  0.121875  0.597778  0.680000
# 2055612  fe58ec1b06db2bb7  /m/04bcr3  0.124375  0.217500  0.612222  0.712222
# 2055613  fe58ec1b06db2bb7  /m/04bcr3  0.308750  0.517500  0.632222  0.864444
# 2055614  fe58ec1b06db2bb7  /m/04bcr3  0.513750  0.903125  0.680000  0.998889
#
#          IsGroupOf
# 2055608          0
# 2055609          0
# 2055610          0
# 2055611          0
# 2055612          0
# 2055613          0
# 2055614          0

# %%
df_vrd.RelationshipLabel.value_counts()
# Out:
# is                194142
# at                111493
# on                 31604
# holds              20986
# plays               8932
# interacts_with      3756
# inside_of           2392
# wears                836
# hits                 593
# under                 34
# Name: RelationshipLabel, dtype: int64

# %%
df_vrd.loc[df_vrd.RelationshipLabel=='is'].LabelName2.value_counts()
# Out:
# /m/083vt     117165
# /m/05z87      36140
# /m/02gy9n     20644
# /m/04lbp      14411
# /m/0dnr7       5782
# Name: LabelName2, dtype: int64

# %%
df_vrd.loc[df_vrd.RelationshipLabel=='is'].shape
# Out:
# (194142, 12)

# %%
is_labels_1 = df_vrd.loc[df_vrd.RelationshipLabel=='is'].LabelName1.unique()
is_labels_1
# Out:
# array(['/m/04bcr3', '/m/04dr76w', '/m/01mzpv', '/m/078n6m', '/m/0342h',
#        '/m/03m3pdh', '/m/03ssj5', '/m/01_5g', '/m/01y9k5', '/m/0cvnqh',
#        '/m/07y_7', '/m/071p9', '/m/05r5c', '/m/01940j', '/m/01s55n',
#        '/m/080hkjn', '/m/026t6', '/m/02p5f1q', '/m/0cmx8', '/m/0dt3t',
#        '/m/0584n8', '/m/04ctx', '/m/02jvh9'], dtype=object)

# %%
is_labels_2 = df_vrd.loc[df_vrd.RelationshipLabel=='is'].LabelName2.unique()
is_labels_2
# Out:
# array(['/m/083vt', '/m/02gy9n', '/m/05z87', '/m/04lbp', '/m/0dnr7'],
#       dtype=object)

# %%
df_box.loc[df_box.LabelName.isin(set(is_labels_1))].shape
# Out:
# (363048, 7)

# %%
df_box_is = df_box.loc[df_box.LabelName.isin(set(is_labels_1))].copy()
df_box_is.head()
# Out:
#              ImageID LabelName      XMin      XMax      YMin      YMax  \
# 3   780db0a7d07a4a20  /m/026t6  0.000000  1.000000  0.345625  0.990000
# 4   780db0a7d07a4a20  /m/026t6  0.271667  0.626667  0.803125  0.999375
# 5   780db0a7d07a4a20  /m/026t6  0.562500  0.999167  0.816875  0.999375
# 6   780db0a7d07a4a20  /m/026t6  0.645000  0.790833  0.801875  0.853125
# 72  780e7ff74d4e3785  /m/026t6  0.623438  0.890625  0.263775  0.656506
#
#     IsGroupOf
# 3          -1
# 4           0
# 5           0
# 6           0
# 72          0

# %%
df_box_is['box_id'] = df_box_is.ImageID + '_' + df_box_is.LabelName + '_' + df_box_is.XMin + '_' + df_box_is.XMax + '_' + df_box_is.YMin + '_' + df_box_is.YMax
df_box_is.head()
# Out:
#              ImageID LabelName      XMin      XMax      YMin      YMax  \
# 3   780db0a7d07a4a20  /m/026t6  0.000000  1.000000  0.345625  0.990000
# 4   780db0a7d07a4a20  /m/026t6  0.271667  0.626667  0.803125  0.999375
# 5   780db0a7d07a4a20  /m/026t6  0.562500  0.999167  0.816875  0.999375
# 6   780db0a7d07a4a20  /m/026t6  0.645000  0.790833  0.801875  0.853125
# 72  780e7ff74d4e3785  /m/026t6  0.623438  0.890625  0.263775  0.656506
#
#     IsGroupOf                                             box_id
# 3          -1  780db0a7d07a4a20_/m/026t6_0.000000_1.000000_0....
# 4           0  780db0a7d07a4a20_/m/026t6_0.271667_0.626667_0....
# 5           0  780db0a7d07a4a20_/m/026t6_0.562500_0.999167_0....
# 6           0  780db0a7d07a4a20_/m/026t6_0.645000_0.790833_0....
# 72          0  780e7ff74d4e3785_/m/026t6_0.623438_0.890625_0....

# %%
df_vrd_is = df_vrd.loc[df_vrd.RelationshipLabel=='is'].copy()
df_vrd_is.head()
# Out:
#             ImageID  LabelName1 LabelName2     XMin1     XMax1     YMin1  \
# 0  fe58ec1b06db2bb7   /m/04bcr3   /m/083vt  0.005000  0.033125  0.580000
# 1  82d16a22f703df5c  /m/04dr76w  /m/02gy9n  0.612000  0.735000  0.418919
# 2  b54d41beabcfd900   /m/01mzpv   /m/083vt  0.372500  0.399375  0.706413
# 8  9a87b10b780dd7e6   /m/01mzpv   /m/083vt  0.556875  0.659375  0.714822
# 9  e4990b198db250d3   /m/01mzpv   /m/083vt  0.138750  0.199375  0.435833
#
#       YMax1     XMin2     XMax2     YMin2     YMax2 RelationshipLabel  \
# 0  0.627778  0.005000  0.033125  0.580000  0.627778                is
# 1  0.950450  0.612000  0.735000  0.418919  0.950450                is
# 2  0.778557  0.372500  0.399375  0.706413  0.778557                is
# 8  0.826454  0.556875  0.659375  0.714822  0.826454                is
# 9  0.505000  0.138750  0.199375  0.435833  0.505000                is
#
#                                               box_id
# 0  fe58ec1b06db2bb7_/m/04bcr3_0.005000_0.033125_0...
# 1  82d16a22f703df5c_/m/04dr76w_0.612000_0.735000_...
# 2  b54d41beabcfd900_/m/01mzpv_0.372500_0.399375_0...
# 8  9a87b10b780dd7e6_/m/01mzpv_0.556875_0.659375_0...
# 9  e4990b198db250d3_/m/01mzpv_0.138750_0.199375_0...

# %%
df_vrd_is['box_id'] = df_vrd_is.ImageID + '_' + df_vrd_is.LabelName1 + '_' + df_vrd_is.XMin1 + '_' + df_vrd_is.XMax1 + '_' + df_vrd_is.YMin1 + '_' + df_vrd_is.YMax1
df_vrd_is.head()
# Out:
#             ImageID  LabelName1 LabelName2     XMin1     XMax1     YMin1  \
# 0  fe58ec1b06db2bb7   /m/04bcr3   /m/083vt  0.005000  0.033125  0.580000
# 1  82d16a22f703df5c  /m/04dr76w  /m/02gy9n  0.612000  0.735000  0.418919
# 2  b54d41beabcfd900   /m/01mzpv   /m/083vt  0.372500  0.399375  0.706413
# 8  9a87b10b780dd7e6   /m/01mzpv   /m/083vt  0.556875  0.659375  0.714822
# 9  e4990b198db250d3   /m/01mzpv   /m/083vt  0.138750  0.199375  0.435833
#
#       YMax1     XMin2     XMax2     YMin2     YMax2 RelationshipLabel  \
# 0  0.627778  0.005000  0.033125  0.580000  0.627778                is
# 1  0.950450  0.612000  0.735000  0.418919  0.950450                is
# 2  0.778557  0.372500  0.399375  0.706413  0.778557                is
# 8  0.826454  0.556875  0.659375  0.714822  0.826454                is
# 9  0.505000  0.138750  0.199375  0.435833  0.505000                is
#
#                                               box_id
# 0  fe58ec1b06db2bb7_/m/04bcr3_0.005000_0.033125_0...
# 1  82d16a22f703df5c_/m/04dr76w_0.612000_0.735000_...
# 2  b54d41beabcfd900_/m/01mzpv_0.372500_0.399375_0...
# 8  9a87b10b780dd7e6_/m/01mzpv_0.556875_0.659375_0...
# 9  e4990b198db250d3_/m/01mzpv_0.138750_0.199375_0...

# %%
df_train_is = df_box_is.set_index('box_id').join(df_vrd_is.set_index('box_id'), on='box_id', rsuffix='dfvrd')
df_train_is.head()
# Out:
#                                                              ImageID  \
# box_id
# 780db0a7d07a4a20_/m/026t6_0.000000_1.000000_0.3...  780db0a7d07a4a20
# 780db0a7d07a4a20_/m/026t6_0.271667_0.626667_0.8...  780db0a7d07a4a20
# 780db0a7d07a4a20_/m/026t6_0.562500_0.999167_0.8...  780db0a7d07a4a20
# 780db0a7d07a4a20_/m/026t6_0.645000_0.790833_0.8...  780db0a7d07a4a20
# 780e7ff74d4e3785_/m/026t6_0.623438_0.890625_0.2...  780e7ff74d4e3785
#
#                                                    LabelName      XMin  \
# box_id
# 780db0a7d07a4a20_/m/026t6_0.000000_1.000000_0.3...  /m/026t6  0.000000
# 780db0a7d07a4a20_/m/026t6_0.271667_0.626667_0.8...  /m/026t6  0.271667
# 780db0a7d07a4a20_/m/026t6_0.562500_0.999167_0.8...  /m/026t6  0.562500
# 780db0a7d07a4a20_/m/026t6_0.645000_0.790833_0.8...  /m/026t6  0.645000
# 780e7ff74d4e3785_/m/026t6_0.623438_0.890625_0.2...  /m/026t6  0.623438
#
#                                                         XMax      YMin  \
# box_id
# 780db0a7d07a4a20_/m/026t6_0.000000_1.000000_0.3...  1.000000  0.345625
# 780db0a7d07a4a20_/m/026t6_0.271667_0.626667_0.8...  0.626667  0.803125
# 780db0a7d07a4a20_/m/026t6_0.562500_0.999167_0.8...  0.999167  0.816875
# 780db0a7d07a4a20_/m/026t6_0.645000_0.790833_0.8...  0.790833  0.801875
# 780e7ff74d4e3785_/m/026t6_0.623438_0.890625_0.2...  0.890625  0.263775
#
#                                                         YMax  IsGroupOf  \
# box_id
# 780db0a7d07a4a20_/m/026t6_0.000000_1.000000_0.3...  0.990000         -1
# 780db0a7d07a4a20_/m/026t6_0.271667_0.626667_0.8...  0.999375          0
# 780db0a7d07a4a20_/m/026t6_0.562500_0.999167_0.8...  0.999375          0
# 780db0a7d07a4a20_/m/026t6_0.645000_0.790833_0.8...  0.853125          0
# 780e7ff74d4e3785_/m/026t6_0.623438_0.890625_0.2...  0.656506          0
#
#                                                    ImageIDdfvrd LabelName1  \
# box_id
# 780db0a7d07a4a20_/m/026t6_0.000000_1.000000_0.3...          NaN        NaN
# 780db0a7d07a4a20_/m/026t6_0.271667_0.626667_0.8...          NaN        NaN
# 780db0a7d07a4a20_/m/026t6_0.562500_0.999167_0.8...          NaN        NaN
# 780db0a7d07a4a20_/m/026t6_0.645000_0.790833_0.8...          NaN        NaN
# 780e7ff74d4e3785_/m/026t6_0.623438_0.890625_0.2...          NaN        NaN
#
#                                                    LabelName2 XMin1 XMax1  \
# box_id
# 780db0a7d07a4a20_/m/026t6_0.000000_1.000000_0.3...        NaN   NaN   NaN
# 780db0a7d07a4a20_/m/026t6_0.271667_0.626667_0.8...        NaN   NaN   NaN
# 780db0a7d07a4a20_/m/026t6_0.562500_0.999167_0.8...        NaN   NaN   NaN
# 780db0a7d07a4a20_/m/026t6_0.645000_0.790833_0.8...        NaN   NaN   NaN
# 780e7ff74d4e3785_/m/026t6_0.623438_0.890625_0.2...        NaN   NaN   NaN
#
#                                                    YMin1 YMax1  XMin2  XMax2  \
# box_id
# 780db0a7d07a4a20_/m/026t6_0.000000_1.000000_0.3...   NaN   NaN    NaN    NaN
# 780db0a7d07a4a20_/m/026t6_0.271667_0.626667_0.8...   NaN   NaN    NaN    NaN
# 780db0a7d07a4a20_/m/026t6_0.562500_0.999167_0.8...   NaN   NaN    NaN    NaN
# 780db0a7d07a4a20_/m/026t6_0.645000_0.790833_0.8...   NaN   NaN    NaN    NaN
# 780e7ff74d4e3785_/m/026t6_0.623438_0.890625_0.2...   NaN   NaN    NaN    NaN
#
#                                                     YMin2  YMax2  \
# box_id
# 780db0a7d07a4a20_/m/026t6_0.000000_1.000000_0.3...    NaN    NaN
# 780db0a7d07a4a20_/m/026t6_0.271667_0.626667_0.8...    NaN    NaN
# 780db0a7d07a4a20_/m/026t6_0.562500_0.999167_0.8...    NaN    NaN
# 780db0a7d07a4a20_/m/026t6_0.645000_0.790833_0.8...    NaN    NaN
# 780e7ff74d4e3785_/m/026t6_0.623438_0.890625_0.2...    NaN    NaN
#
#                                                    RelationshipLabel
# box_id
# 780db0a7d07a4a20_/m/026t6_0.000000_1.000000_0.3...               NaN
# 780db0a7d07a4a20_/m/026t6_0.271667_0.626667_0.8...               NaN
# 780db0a7d07a4a20_/m/026t6_0.562500_0.999167_0.8...               NaN
# 780db0a7d07a4a20_/m/026t6_0.645000_0.790833_0.8...               NaN
# 780e7ff74d4e3785_/m/026t6_0.623438_0.890625_0.2...               NaN

# %%
print(df_train_is.shape, df_box_is.shape, df_vrd_is.shape)
# Out:
# (376857, 19) (363048, 8) (194142, 13)

# %%
df_train_is.RelationshipLabel = df_train_is.RelationshipLabel.fillna('none')

# %%
df_train_is.sample(10)
# Out:
#                                                              ImageID  \
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....  14c8646a2edbad78
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....  47b0e5e9d1d5b1db
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...  6b1591f18ff1f889
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....  3e718a3366a09b0f
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....  9920ce2c5e89c0b8
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....  2896b7972bc8becc
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....  786cfb80be0c09d0
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....  92ae6887cdef1463
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....  2cc79e66d0937e91
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...  a4c9ee2595d18c1a
#
#                                                      LabelName      XMin  \
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....   /m/04bcr3  0.582500
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....   /m/01mzpv  0.056250
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...  /m/03m3pdh  0.000000
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....   /m/01mzpv  0.262695
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....   /m/01mzpv  0.045000
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....   /m/01mzpv  0.161250
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....   /m/01mzpv  0.330000
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....   /m/01mzpv  0.963125
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....   /m/04bcr3  0.000000
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...    /m/07y_7  0.726250
#
#                                                         XMax      YMin  \
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....  0.628750  0.569167
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....  0.253750  0.667600
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...  0.298125  0.456504
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....  0.902344  0.429619
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....  0.370833  0.290000
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....  0.386875  0.528333
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....  0.411875  0.964167
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....  0.999375  0.170732
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....  0.679375  0.534709
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...  0.900625  0.061692
#
#                                                         YMax  IsGroupOf  \
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....  0.608333          0
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....  0.999066          0
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...  0.892295          0
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....  0.780059          1
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....  0.681875          0
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....  0.720000          0
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....  0.999167          0
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....  0.211847          0
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....  0.999062          0
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...  0.359204          0
#
#                                                         ImageIDdfvrd  \
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....  14c8646a2edbad78
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....               NaN
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...  6b1591f18ff1f889
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....               NaN
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....  9920ce2c5e89c0b8
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....               NaN
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....  786cfb80be0c09d0
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....               NaN
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....  2cc79e66d0937e91
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...               NaN
#
#                                                     LabelName1 LabelName2  \
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....   /m/04bcr3   /m/083vt
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....         NaN        NaN
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...  /m/03m3pdh   /m/0dnr7
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....         NaN        NaN
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....   /m/01mzpv   /m/083vt
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....         NaN        NaN
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....   /m/01mzpv   /m/04lbp
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....         NaN        NaN
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....   /m/04bcr3   /m/083vt
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...         NaN        NaN
#
#                                                        XMin1     XMax1  \
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....  0.582500  0.628750
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....       NaN       NaN
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...  0.000000  0.298125
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....       NaN       NaN
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....  0.045000  0.370833
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....       NaN       NaN
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....  0.330000  0.411875
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....       NaN       NaN
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....  0.000000  0.679375
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...       NaN       NaN
#
#                                                        YMin1     YMax1  \
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....  0.569167  0.608333
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....       NaN       NaN
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...  0.456504  0.892295
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....       NaN       NaN
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....  0.290000  0.681875
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....       NaN       NaN
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....  0.964167  0.999167
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....       NaN       NaN
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....  0.534709  0.999062
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...       NaN       NaN
#
#                                                      XMin2     XMax2  \
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....  0.5825  0.628750
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....     NaN       NaN
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...  0.0000  0.298125
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....     NaN       NaN
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....  0.0450  0.370833
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....     NaN       NaN
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....  0.3300  0.411875
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....     NaN       NaN
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....  0.0000  0.679375
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...     NaN       NaN
#
#                                                        YMin2     YMax2  \
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....  0.569167  0.608333
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....       NaN       NaN
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...  0.456504  0.892295
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....       NaN       NaN
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....  0.290000  0.681875
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....       NaN       NaN
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....  0.964167  0.999167
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....       NaN       NaN
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....  0.534709  0.999062
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...       NaN       NaN
#
#                                                    RelationshipLabel
# box_id
# 14c8646a2edbad78_/m/04bcr3_0.582500_0.628750_0....                is
# 47b0e5e9d1d5b1db_/m/01mzpv_0.056250_0.253750_0....              none
# 6b1591f18ff1f889_/m/03m3pdh_0.000000_0.298125_0...                is
# 3e718a3366a09b0f_/m/01mzpv_0.262695_0.902344_0....              none
# 9920ce2c5e89c0b8_/m/01mzpv_0.045000_0.370833_0....                is
# 2896b7972bc8becc_/m/01mzpv_0.161250_0.386875_0....              none
# 786cfb80be0c09d0_/m/01mzpv_0.330000_0.411875_0....                is
# 92ae6887cdef1463_/m/01mzpv_0.963125_0.999375_0....              none
# 2cc79e66d0937e91_/m/04bcr3_0.000000_0.679375_0....                is
# a4c9ee2595d18c1a_/m/07y_7_0.726250_0.900625_0.0...              none

# %%
df_vrd.loc[df_vrd.RelationshipLabel=='is'].LabelName1.value_counts()
# Out:
# /m/01mzpv     70456
# /m/04bcr3     48975
# /m/04dr76w    27270
# /m/0342h      13444
# /m/01y9k5      7472
# /m/0cvnqh      5089
# /m/080hkjn     3820
# /m/078n6m      3696
# /m/026t6       2906
# /m/07y_7       2550
# /m/03m3pdh     2129
# /m/03ssj5      1370
# /m/01940j      1276
# /m/05r5c       1182
# /m/01s55n       867
# /m/01_5g        574
# /m/0584n8       290
# /m/071p9        204
# /m/02p5f1q      195
# /m/0cmx8        151
# /m/02jvh9       141
# /m/0dt3t         55
# /m/04ctx         30
# Name: LabelName1, dtype: int64

# %%
classes_is = df_vrd.loc[df_vrd.RelationshipLabel=='is'].LabelName1.unique().tolist()

# %%
classes_is
# Out:
# ['/m/04bcr3',
#  '/m/04dr76w',
#  '/m/01mzpv',
#  '/m/078n6m',
#  '/m/0342h',
#  '/m/03m3pdh',
#  '/m/03ssj5',
#  '/m/01_5g',
#  '/m/01y9k5',
#  '/m/0cvnqh',
#  '/m/07y_7',
#  '/m/071p9',
#  '/m/05r5c',
#  '/m/01940j',
#  '/m/01s55n',
#  '/m/080hkjn',
#  '/m/026t6',
#  '/m/02p5f1q',
#  '/m/0cmx8',
#  '/m/0dt3t',
#  '/m/0584n8',
#  '/m/04ctx',
#  '/m/02jvh9']

# %%
df_classes = pd.read_csv(os.path.join(DATA_DIR, 'challenge-2019-classes-vrd.csv'), names=['classes', 'desc'])
df_classes.head()
# Out:
#     classes        desc
# 0  /m/05r5c       Piano
# 1  /m/01599        Beer
# 2  /m/01_5g  Chopsticks
# 3  /m/01yrx         Cat
# 4  /m/04_sv  Motorcycle

# %%
df_detect_classes = pd.read_csv(os.path.join(DETECT_DATA_DIR, 'challenge-2019-classes-description-500.csv'), names=['classes', 'desc2'])
df_detect_classes.head()
# Out:
#      classes       desc2
# 0  /m/061hd_  Infant bed
# 1   /m/06m11        Rose
# 2   /m/03120        Flag
# 3  /m/01kb5b  Flashlight
# 4  /m/0120dh  Sea turtle

# %%
df_join = df_classes.set_index('classes').join(df_detect_classes.set_index('classes'), on='classes')
df_join.head(50)
# Out:
#                            desc                desc2
# classes
# /m/05r5c                  Piano                Piano
# /m/01599                   Beer                 Beer
# /m/01_5g             Chopsticks           Chopsticks
# /m/01yrx                    Cat                  Cat
# /m/04_sv             Motorcycle           Motorcycle
# /m/0h8my_4        Tennis racket        Tennis racket
# /m/01226z              Football             Football
# /m/050k8           Mobile phone         Mobile phone
# /m/0l14j_                 Flute                Flute
# /m/05ctyq           Tennis ball          Tennis ball
# /m/01mzpv                 Chair                Chair
# /m/03bt1vf                Woman                Woman
# /m/01bl7v                   Boy                  Boy
# /m/078n6m          Coffee table         Coffee table
# /m/080hkjn              Handbag              Handbag
# /m/0dt3t                   Fork                 Fork
# /m/05r655                  Girl                 Girl
# /m/02p5f1q           Coffee cup           Coffee cup
# /m/07y_7                 Violin               Violin
# /m/01940j              Backpack             Backpack
# /m/04ctx                  Knife                Knife
# /m/06__v              Snowboard            Snowboard
# /m/0wdt60w           Rugby ball           Rugby ball
# /m/078jl                  Snake                Snake
# /m/029bxz                  Oven                 Oven
# /m/0fx9l         Microwave oven       Microwave oven
# /m/04yx4                    Man                  Man
# /m/0cvnqh                 Bench                Bench
# /m/01y9k5                  Desk                 Desk
# /m/01s55n              Suitcase             Suitcase
# /m/03m3pdh             Sofa bed             Sofa bed
# /m/03k3r                  Horse                Horse
# /m/0hg7b             Microphone           Microphone
# /m/05_5p_0  Table tennis racket  Table tennis racket
# /m/08pbxl                Monkey               Monkey
# /m/019w40             Surfboard            Surfboard
# /m/04bcr3                 Table                Table
# /m/04dr76w               Bottle               Bottle
# /m/02jvh9                   Mug                  Mug
# /m/09tvcd            Wine glass           Wine glass
# /m/026t6                   Drum                 Drum
# /m/0bt9lr                   Dog                  Dog
# /m/0342h                 Guitar               Guitar
# /m/071p9                    Ski                  Ski
# /m/03ssj5                   Bed                  Bed
# /m/0cmx8                  Spoon                Spoon
# /m/0584n8             Briefcase            Briefcase
# /m/03qrc                Hamster              Hamster
# /m/0k4j                     Car                  Car
# /m/0199g                Bicycle              Bicycle

# %%
df_join.shape
# Out:
# (57, 2)

# %%
df_trip = pd.read_csv(os.path.join(DATA_DIR, 'challenge-2019-relationship-triplets.csv'))
df_trip.head()
# Out:
#   LabelName1  LabelName2 RelationshipLabel
# 0   /m/01599   /m/04bcr3                on
# 1  /m/05r655  /m/0h8my_4             holds
# 2  /m/05r655    /m/03k3r                on
# 3   /m/04yx4   /m/0l14j_             holds
# 4  /m/05r655  /m/080hkjn             wears

# %%
df_trip.loc[df_trip.RelationshipLabel=='is'].shape
# Out:
# (42, 3)

# %%
df_trip.shape
# Out:
# (329, 3)
