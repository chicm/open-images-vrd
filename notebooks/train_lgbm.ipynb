# %%
# !pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading https://files.pythonhosted.org/packages/77/0f/5157e6b153b3d4a70dc5fbe2ab6f209604197590f387f03177b7a249ac60/lightgbm-2.2.3-py2.py3-none-manylinux1_x86_64.whl (1.2MB)
#     100% |████████████████████████████████| 1.2MB 14.5MB/s ta 0:00:01
# Requirement already satisfied: scipy in /mnt/chicm/anaconda3/lib/python3.7/site-packages (from lightgbm) (1.2.1)
# Requirement already satisfied: scikit-learn in /mnt/chicm/anaconda3/lib/python3.7/site-packages (from lightgbm) (0.20.3)
# Requirement already satisfied: numpy in /mnt/chicm/anaconda3/lib/python3.7/site-packages (from lightgbm) (1.16.2)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-2.2.3

# %%
import os
import sys
import argparse
import numpy as np
import pandas as pd
import random
import torch
import json
import cv2
from tqdm import tqdm
import pickle
import glob
import os.path as osp
from multiprocessing import Pool
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score

sys.path.append("../vrd")
from utils import get_iou, get_image_size

# %%
from train_catboost import classes_1, classes_2

# %%
import lightgbm as lgb

# %%
from sklearn.preprocessing import LabelEncoder

# %%
DATA_DIR='/mnt/chicm/data/open-images/relation'

# %%
neg_sample_fn = '../vrd/lb23578/df_neg_small_2.csv'

# %%
def parallel_apply(df, func, n_cores=24):
    #ncores = 24
    df_split = np.array_split(df, n_cores)
    pool = Pool(n_cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    return df

# %%
def add_features(df):
    df['iou'] = df.apply(lambda row: get_iou(row), axis=1)
    #df['ratio'] = df.apply(lambda row: get_img_ratio(row), axis=1)
    return df

# %%
le1, le2, ley = LabelEncoder(), LabelEncoder(), LabelEncoder()

# %%
def get_train_data():
    df_vrd = pd.read_csv(os.path.join(DATA_DIR, 'challenge-2019-train-vrd.csv'))
    df_pos = df_vrd.loc[df_vrd.RelationshipLabel!='is'].copy()

    df_neg = pd.read_csv(neg_sample_fn)

    df_train = pd.concat([df_pos, df_neg], axis=0, sort=False)
    print(df_train.shape)

    df_train = shuffle(df_train)
    df_train = parallel_apply(df_train, add_features)
    print(df_train.head())

    y = df_train.RelationshipLabel
    X = df_train.drop(['ImageID', 'RelationshipLabel'], axis=1)
    
    le1.fit(X.LabelName1)
    le2.fit(X.LabelName2)
    ley.fit(y)
    
    X.LabelName1 = le1.transform(X.LabelName1)
    X.LabelName2 = le2.transform(X.LabelName2)
    y = ley.transform(y)
    
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1)
    return X_train, X_val, y_train, y_val

# %%
#def train():
X_train, X_val, y_train, y_val = get_train_data()
print(X_train.dtypes)
categorical_feature_indices = np.where(X_train.dtypes != np.float)[0]
print(categorical_feature_indices)
# Out:
# (335187, 12)
#                  ImageID  LabelName1 LabelName2     XMin1     XMax1     YMin1  \
# 235521  6c74a94450420453   /m/01mzpv  /m/04bcr3  0.360000  0.409375  0.504167
# 66327   678c2b477ec9e760   /m/01mzpv  /m/01mzpv  0.883125  0.976250  0.461667
# 212297  ce449209df75a8c6    /m/04yx4  /m/078n6m  0.168889  0.287778  0.142222
# 109589  b1ff4494eb6d654a  /m/03bt1vf  /m/019w40  0.520000  0.761875  0.053471
# 71898   5c74aca98a04b456   /m/05r655  /m/0bt9lr  0.710000  0.978125  0.223265
#
#            YMax1     XMin2     XMax2     YMin2     YMax2 RelationshipLabel  \
# 235521  0.609167  0.371250  0.423125  0.496667  0.558333                at
# 66327   0.580000  0.006250  0.152500  0.578333  0.884167              none
# 212297  0.601482  0.110000  0.316667  0.405926  0.814815                at
# 109589  0.999062  0.548750  0.980625  0.638837  0.926829              none
# 71898   0.999062  0.695625  0.798125  0.393058  0.814259    interacts_with
#
#              iou
# 235521  0.326797
# 66327   0.000000
# 212297  0.200675
# 109589  0.210406
# 71898   0.173396
# LabelName1      int64
# LabelName2      int64
# XMin1         float64
# XMax1         float64
# YMin1         float64
# YMax1         float64
# XMin2         float64
# XMax2         float64
# YMin2         float64
# YMax2         float64
# iou           float64
# dtype: object
# [0 1]

# %%
categorical_feature_indices
# Out:
# array([0, 1])

# %%
ley.classes_
# Out:
# array(['at', 'hits', 'holds', 'inside_of', 'interacts_with', 'none', 'on',
#        'plays', 'under', 'wears'], dtype=object)

# %%
train_data = lgb.Dataset(X_train, label=y_train, categorical_feature=categorical_feature_indices.tolist())
test_data = lgb.Dataset(X_val, label=y_val)

# %%
parameters = {
    'application': 'binary',
    'objective': 'binary',
    #'metric': 'auc',
    'metric': 'accuracy',
    'is_unbalance': 'true',
    'boosting': 'gbdt',
    'num_leaves': 31,
    'feature_fraction': 0.5,
    'bagging_fraction': 0.5,
    'bagging_freq': 20,
    'learning_rate': 0.05,
    'verbose': 0
}

params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'multiclass',
    'num_class':10,
    'metric': 'multi_logloss',
    'learning_rate': 0.05,
    'max_depth': 7,
    'num_leaves': 17,
    'feature_fraction': 0.4,
    'bagging_fraction': 0.6,
    'bagging_freq': 17
}

model = lgb.train(
    params,
    train_data,
    valid_sets=test_data,
    num_boost_round=5000,
    early_stopping_rounds=100
)

#
# Create a submission
#
# Out:
# [1]	valid_0's multi_logloss: 1.26276
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's multi_logloss: 1.2232
# [3]	valid_0's multi_logloss: 1.17867
# [4]	valid_0's multi_logloss: 1.14533
# [5]	valid_0's multi_logloss: 1.11683
# [6]	valid_0's multi_logloss: 1.08263
# [7]	valid_0's multi_logloss: 1.05429
# [8]	valid_0's multi_logloss: 1.02079
# [9]	valid_0's multi_logloss: 0.993258
# [10]	valid_0's multi_logloss: 0.968895
# [11]	valid_0's multi_logloss: 0.928751
# [12]	valid_0's multi_logloss: 0.901151
# [13]	valid_0's multi_logloss: 0.876097
# [14]	valid_0's multi_logloss: 0.857213
# [15]	valid_0's multi_logloss: 0.835699
# [16]	valid_0's multi_logloss: 0.812119
# [17]	valid_0's multi_logloss: 0.801389
# [18]	valid_0's multi_logloss: 0.793859
# [19]	valid_0's multi_logloss: 0.768201
# [20]	valid_0's multi_logloss: 0.75272
# [21]	valid_0's multi_logloss: 0.732962
# [22]	valid_0's multi_logloss: 0.714995
# [23]	valid_0's multi_logloss: 0.692842
# [24]	valid_0's multi_logloss: 0.674878
# [25]	valid_0's multi_logloss: 0.662695
# [26]	valid_0's multi_logloss: 0.652088
# [27]	valid_0's multi_logloss: 0.643148
# [28]	valid_0's multi_logloss: 0.636309
# [29]	valid_0's multi_logloss: 0.622908
# [30]	valid_0's multi_logloss: 0.614257
# [31]	valid_0's multi_logloss: 0.604828
# [32]	valid_0's multi_logloss: 0.597634
# [33]	valid_0's multi_logloss: 0.587307
# [34]	valid_0's multi_logloss: 0.579591
# [35]	valid_0's multi_logloss: 0.56976
# [36]	valid_0's multi_logloss: 0.559826
# [37]	valid_0's multi_logloss: 0.554729
# [38]	valid_0's multi_logloss: 0.541722
# [39]	valid_0's multi_logloss: 0.533751
# [40]	valid_0's multi_logloss: 0.52819
# [41]	valid_0's multi_logloss: 0.522713
# [42]	valid_0's multi_logloss: 0.517555
# [43]	valid_0's multi_logloss: 0.509016
# [44]	valid_0's multi_logloss: 0.508789
# [45]	valid_0's multi_logloss: 0.498338
# [46]	valid_0's multi_logloss: 0.489524
# [47]	valid_0's multi_logloss: 0.482555
# [48]	valid_0's multi_logloss: 0.472889
# [49]	valid_0's multi_logloss: 0.465336
# [50]	valid_0's multi_logloss: 0.456814
# [51]	valid_0's multi_logloss: 0.450346
# [52]	valid_0's multi_logloss: 0.445281
# [53]	valid_0's multi_logloss: 0.441567
# [54]	valid_0's multi_logloss: 0.437525
# [55]	valid_0's multi_logloss: 0.430755
# [56]	valid_0's multi_logloss: 0.427693
# [57]	valid_0's multi_logloss: 0.419573
# [58]	valid_0's multi_logloss: 0.410504
# [59]	valid_0's multi_logloss: 0.4055
# [60]	valid_0's multi_logloss: 0.400899
# [61]	valid_0's multi_logloss: 0.398763
# [62]	valid_0's multi_logloss: 0.393265
# [63]	valid_0's multi_logloss: 0.38734
# [64]	valid_0's multi_logloss: 0.384913
# [65]	valid_0's multi_logloss: 0.381593
# [66]	valid_0's multi_logloss: 0.379432
# [67]	valid_0's multi_logloss: 0.37635
# [68]	valid_0's multi_logloss: 0.371828
# [69]	valid_0's multi_logloss: 0.369274
# [70]	valid_0's multi_logloss: 0.362799
# [71]	valid_0's multi_logloss: 0.357506
# [72]	valid_0's multi_logloss: 0.35361
# [73]	valid_0's multi_logloss: 0.349749
# [74]	valid_0's multi_logloss: 0.344875
# [75]	valid_0's multi_logloss: 0.340633
# [76]	valid_0's multi_logloss: 0.337714
# [77]	valid_0's multi_logloss: 0.334144
# [78]	valid_0's multi_logloss: 0.329057
# [79]	valid_0's multi_logloss: 0.325448
# [80]	valid_0's multi_logloss: 0.322618
# [81]	valid_0's multi_logloss: 0.320699
# [82]	valid_0's multi_logloss: 0.316789
# [83]	valid_0's multi_logloss: 0.312057
# [84]	valid_0's multi_logloss: 0.309579
# [85]	valid_0's multi_logloss: 0.307275
# [86]	valid_0's multi_logloss: 0.340518
# [87]	valid_0's multi_logloss: 0.333753
# [88]	valid_0's multi_logloss: 0.307884
# [89]	valid_0's multi_logloss: 0.304616
# [90]	valid_0's multi_logloss: 0.303395
# [91]	valid_0's multi_logloss: 0.298695
# [92]	valid_0's multi_logloss: 0.342802
# [93]	valid_0's multi_logloss: 0.2987
# [94]	valid_0's multi_logloss: 0.294602
# [95]	valid_0's multi_logloss: 0.344624
# [96]	valid_0's multi_logloss: 0.301736
# [97]	valid_0's multi_logloss: 0.298512
# [98]	valid_0's multi_logloss: 0.297369
# [99]	valid_0's multi_logloss: 0.292061
# [100]	valid_0's multi_logloss: 0.289804
# [101]	valid_0's multi_logloss: 0.2894
# [102]	valid_0's multi_logloss: 0.349838
# [103]	valid_0's multi_logloss: 0.317422
# [104]	valid_0's multi_logloss: 0.306114
# [105]	valid_0's multi_logloss: 0.293766
# [106]	valid_0's multi_logloss: 0.290821
# [107]	valid_0's multi_logloss: 0.286384
# [108]	valid_0's multi_logloss: 0.283113
# [109]	valid_0's multi_logloss: 0.280335
# [110]	valid_0's multi_logloss: 0.299455
# [111]	valid_0's multi_logloss: 0.286206
# [112]	valid_0's multi_logloss: 0.281985
# [113]	valid_0's multi_logloss: 0.277951
# [114]	valid_0's multi_logloss: 0.274627
# [115]	valid_0's multi_logloss: 0.272177
# [116]	valid_0's multi_logloss: 0.268624
# [117]	valid_0's multi_logloss: 0.267193
# [118]	valid_0's multi_logloss: 0.291148
# [119]	valid_0's multi_logloss: 0.275163
# [120]	valid_0's multi_logloss: 0.272654
# [121]	valid_0's multi_logloss: 0.267309
# [122]	valid_0's multi_logloss: 0.262035
# [123]	valid_0's multi_logloss: 0.257314
# [124]	valid_0's multi_logloss: 0.256045
# [125]	valid_0's multi_logloss: 0.253824
# [126]	valid_0's multi_logloss: 0.25255
# [127]	valid_0's multi_logloss: 0.249781
# [128]	valid_0's multi_logloss: 0.248359
# [129]	valid_0's multi_logloss: 0.247326
# [130]	valid_0's multi_logloss: 0.245616
# [131]	valid_0's multi_logloss: 0.244855
# [132]	valid_0's multi_logloss: 0.243203
# [133]	valid_0's multi_logloss: 0.242631
# [134]	valid_0's multi_logloss: 0.240931
# [135]	valid_0's multi_logloss: 0.24022
# [136]	valid_0's multi_logloss: 0.239469
# [137]	valid_0's multi_logloss: 0.237753
# [138]	valid_0's multi_logloss: 0.298987
# [139]	valid_0's multi_logloss: 0.266388
# [140]	valid_0's multi_logloss: 0.256612
# [141]	valid_0's multi_logloss: 0.248893
# [142]	valid_0's multi_logloss: 0.361785
# [143]	valid_0's multi_logloss: 0.333149
# [144]	valid_0's multi_logloss: 0.303292
# [145]	valid_0's multi_logloss: 0.301032
# [146]	valid_0's multi_logloss: 0.285425
# [147]	valid_0's multi_logloss: 0.274063
# [148]	valid_0's multi_logloss: 0.270149
# [149]	valid_0's multi_logloss: 0.264018
# [150]	valid_0's multi_logloss: 0.564725
# [151]	valid_0's multi_logloss: 0.514472
# [152]	valid_0's multi_logloss: 0.469329
# [153]	valid_0's multi_logloss: 0.433455
# [154]	valid_0's multi_logloss: 0.411497
# [155]	valid_0's multi_logloss: 0.380279
# [156]	valid_0's multi_logloss: 0.36804
# [157]	valid_0's multi_logloss: 0.352093
# [158]	valid_0's multi_logloss: 0.339228
# [159]	valid_0's multi_logloss: 0.326191
# [160]	valid_0's multi_logloss: 0.315062
# [161]	valid_0's multi_logloss: 0.306986
# [162]	valid_0's multi_logloss: 0.300342
# [163]	valid_0's multi_logloss: 0.293385
# [164]	valid_0's multi_logloss: 0.286588
# [165]	valid_0's multi_logloss: 0.278411
# [166]	valid_0's multi_logloss: 0.27351
# [167]	valid_0's multi_logloss: 0.266092
# [168]	valid_0's multi_logloss: 0.260065
# [169]	valid_0's multi_logloss: 0.256
# [170]	valid_0's multi_logloss: 0.252749
# [171]	valid_0's multi_logloss: 0.248228
# [172]	valid_0's multi_logloss: 0.245922
# [173]	valid_0's multi_logloss: 0.242722
# [174]	valid_0's multi_logloss: 0.239859
# [175]	valid_0's multi_logloss: 0.23715
# [176]	valid_0's multi_logloss: 0.236
# [177]	valid_0's multi_logloss: 0.232577
# [178]	valid_0's multi_logloss: 0.230906
# [179]	valid_0's multi_logloss: 0.230437
# [180]	valid_0's multi_logloss: 0.229057
# [181]	valid_0's multi_logloss: 0.230143
# [182]	valid_0's multi_logloss: 0.228689
# [183]	valid_0's multi_logloss: 0.226735
# [184]	valid_0's multi_logloss: 0.224114
# [185]	valid_0's multi_logloss: 0.222766
# [186]	valid_0's multi_logloss: 0.22132
# [187]	valid_0's multi_logloss: 0.220374
# [188]	valid_0's multi_logloss: 0.218453
# [189]	valid_0's multi_logloss: 0.2152
# [190]	valid_0's multi_logloss: 0.214085
# [191]	valid_0's multi_logloss: 0.213245
# [192]	valid_0's multi_logloss: 0.212255
# [193]	valid_0's multi_logloss: 0.210895
# [194]	valid_0's multi_logloss: 0.209726
# [195]	valid_0's multi_logloss: 0.208793
# [196]	valid_0's multi_logloss: 0.207364
# [197]	valid_0's multi_logloss: 0.20597
# [198]	valid_0's multi_logloss: 0.205114
# [199]	valid_0's multi_logloss: 0.204495
# [200]	valid_0's multi_logloss: 0.204235
# [201]	valid_0's multi_logloss: 0.203677
# [202]	valid_0's multi_logloss: 0.202467
# [203]	valid_0's multi_logloss: 0.200961
# [204]	valid_0's multi_logloss: 0.20027
# [205]	valid_0's multi_logloss: 0.199712
# [206]	valid_0's multi_logloss: 0.199157
# [207]	valid_0's multi_logloss: 0.198441
# [208]	valid_0's multi_logloss: 0.1985
# [209]	valid_0's multi_logloss: 0.198944
# [210]	valid_0's multi_logloss: 0.198146
# [211]	valid_0's multi_logloss: 0.202662
# [212]	valid_0's multi_logloss: 0.199697
# [213]	valid_0's multi_logloss: 0.198984
# [214]	valid_0's multi_logloss: 0.198403
# [215]	valid_0's multi_logloss: 0.197571
# [216]	valid_0's multi_logloss: 0.199462
# [217]	valid_0's multi_logloss: 0.199328
# [218]	valid_0's multi_logloss: 0.198904
# [219]	valid_0's multi_logloss: 0.199091
# [220]	valid_0's multi_logloss: 0.198629
# [221]	valid_0's multi_logloss: 0.198117
# [222]	valid_0's multi_logloss: 0.19769
# [223]	valid_0's multi_logloss: 0.197277
# [224]	valid_0's multi_logloss: 0.196233
# [225]	valid_0's multi_logloss: 0.195626
# [226]	valid_0's multi_logloss: 0.19523
# [227]	valid_0's multi_logloss: 0.194873
# [228]	valid_0's multi_logloss: 0.1935
# [229]	valid_0's multi_logloss: 0.193362
# [230]	valid_0's multi_logloss: 0.194078
# [231]	valid_0's multi_logloss: 0.197153
# [232]	valid_0's multi_logloss: 0.196611
# [233]	valid_0's multi_logloss: 0.196035
# [234]	valid_0's multi_logloss: 0.195624
# [235]	valid_0's multi_logloss: 0.195455
# [236]	valid_0's multi_logloss: 0.195163
# [237]	valid_0's multi_logloss: 0.19471
# [238]	valid_0's multi_logloss: 0.198476
# [239]	valid_0's multi_logloss: 0.198039
# [240]	valid_0's multi_logloss: 0.197329
# [241]	valid_0's multi_logloss: 0.195949
# [242]	valid_0's multi_logloss: 0.195439
# [243]	valid_0's multi_logloss: 0.194868
# [244]	valid_0's multi_logloss: 0.194567
# [245]	valid_0's multi_logloss: 0.194151
# [246]	valid_0's multi_logloss: 0.19387
# [247]	valid_0's multi_logloss: 0.193521
# [248]	valid_0's multi_logloss: 0.196408
# [249]	valid_0's multi_logloss: 0.195737
# [250]	valid_0's multi_logloss: 0.195416
# [251]	valid_0's multi_logloss: 0.195065
# [252]	valid_0's multi_logloss: 0.194602
# [253]	valid_0's multi_logloss: 0.194168
# [254]	valid_0's multi_logloss: 0.194951
# [255]	valid_0's multi_logloss: 0.194046
# [256]	valid_0's multi_logloss: 0.193387
# [257]	valid_0's multi_logloss: 0.193032
# [258]	valid_0's multi_logloss: 0.192656
# [259]	valid_0's multi_logloss: 0.192282
# [260]	valid_0's multi_logloss: 0.19124
# [261]	valid_0's multi_logloss: 0.19085
# [262]	valid_0's multi_logloss: 0.192075
# [263]	valid_0's multi_logloss: 0.191851
# [264]	valid_0's multi_logloss: 0.191508
# [265]	valid_0's multi_logloss: 0.191295
# [266]	valid_0's multi_logloss: 0.190895
# [267]	valid_0's multi_logloss: 0.190716
# [268]	valid_0's multi_logloss: 0.190471
# [269]	valid_0's multi_logloss: 0.190267
# [270]	valid_0's multi_logloss: 0.191018
# [271]	valid_0's multi_logloss: 0.191243
# [272]	valid_0's multi_logloss: 0.191162
# [273]	valid_0's multi_logloss: 0.18996
# [274]	valid_0's multi_logloss: 0.189728
# [275]	valid_0's multi_logloss: 0.19062
# [276]	valid_0's multi_logloss: 0.189311
# [277]	valid_0's multi_logloss: 0.18908
# [278]	valid_0's multi_logloss: 0.188536
# [279]	valid_0's multi_logloss: 0.188271
# [280]	valid_0's multi_logloss: 0.193017
# [281]	valid_0's multi_logloss: 0.18734
# [282]	valid_0's multi_logloss: 0.186627
# [283]	valid_0's multi_logloss: 0.185998
# [284]	valid_0's multi_logloss: 0.185806
# [285]	valid_0's multi_logloss: 0.187171
# [286]	valid_0's multi_logloss: 0.186848
# [287]	valid_0's multi_logloss: 0.186842
# [288]	valid_0's multi_logloss: 0.186559
# [289]	valid_0's multi_logloss: 0.186352
# [290]	valid_0's multi_logloss: 0.185788
# [291]	valid_0's multi_logloss: 0.185912
# [292]	valid_0's multi_logloss: 0.185402
# [293]	valid_0's multi_logloss: 0.186237
# [294]	valid_0's multi_logloss: 0.185936
# [295]	valid_0's multi_logloss: 0.185621
# [296]	valid_0's multi_logloss: 0.18542
# [297]	valid_0's multi_logloss: 0.185795
# [298]	valid_0's multi_logloss: 0.186492
# [299]	valid_0's multi_logloss: 0.186193
# [300]	valid_0's multi_logloss: 0.185961
# [301]	valid_0's multi_logloss: 0.186147
# [302]	valid_0's multi_logloss: 0.18614
# [303]	valid_0's multi_logloss: 0.185568
# [304]	valid_0's multi_logloss: 0.185385
# [305]	valid_0's multi_logloss: 0.185571
# [306]	valid_0's multi_logloss: 0.185367
# [307]	valid_0's multi_logloss: 0.187348
# [308]	valid_0's multi_logloss: 0.187102
# [309]	valid_0's multi_logloss: 0.186833
# [310]	valid_0's multi_logloss: 0.18653
# [311]	valid_0's multi_logloss: 0.18787
# [312]	valid_0's multi_logloss: 0.187494
# [313]	valid_0's multi_logloss: 0.187443
# [314]	valid_0's multi_logloss: 0.187336
# [315]	valid_0's multi_logloss: 0.18664
# [316]	valid_0's multi_logloss: 0.186417
# [317]	valid_0's multi_logloss: 0.185908
# [318]	valid_0's multi_logloss: 0.188133
# [319]	valid_0's multi_logloss: 0.188243
# [320]	valid_0's multi_logloss: 0.187709
# [321]	valid_0's multi_logloss: 0.18658
# [322]	valid_0's multi_logloss: 0.187293
# [323]	valid_0's multi_logloss: 0.188506
# [324]	valid_0's multi_logloss: 0.187915
# [325]	valid_0's multi_logloss: 0.187583
# [326]	valid_0's multi_logloss: 0.187991
# [327]	valid_0's multi_logloss: 0.18715
# [328]	valid_0's multi_logloss: 0.18972
# [329]	valid_0's multi_logloss: 0.187823
# [330]	valid_0's multi_logloss: 0.187553
# [331]	valid_0's multi_logloss: 0.185653
# [332]	valid_0's multi_logloss: 0.185108
# [333]	valid_0's multi_logloss: 0.214404
# [334]	valid_0's multi_logloss: 0.210546
# [335]	valid_0's multi_logloss: 0.207143
# [336]	valid_0's multi_logloss: 0.202617
# [337]	valid_0's multi_logloss: 0.197958
# [338]	valid_0's multi_logloss: 0.197454
# [339]	valid_0's multi_logloss: 0.194202
# [340]	valid_0's multi_logloss: 0.193675
# [341]	valid_0's multi_logloss: 0.192989
# [342]	valid_0's multi_logloss: 0.192622
# [343]	valid_0's multi_logloss: 0.190553
# [344]	valid_0's multi_logloss: 0.190224
# [345]	valid_0's multi_logloss: 0.188424
# [346]	valid_0's multi_logloss: 0.187738
# [347]	valid_0's multi_logloss: 0.187388
# [348]	valid_0's multi_logloss: 0.187292
# [349]	valid_0's multi_logloss: 0.185885
# [350]	valid_0's multi_logloss: 0.184136
# [351]	valid_0's multi_logloss: 0.183009
# [352]	valid_0's multi_logloss: 0.18434
# [353]	valid_0's multi_logloss: 0.184838
# [354]	valid_0's multi_logloss: 0.183888
# [355]	valid_0's multi_logloss: 0.184202
# [356]	valid_0's multi_logloss: 0.184479
# [357]	valid_0's multi_logloss: 0.183909
# [358]	valid_0's multi_logloss: 0.183717
# [359]	valid_0's multi_logloss: 0.180082
# [360]	valid_0's multi_logloss: 0.183428
# [361]	valid_0's multi_logloss: 0.181577
# [362]	valid_0's multi_logloss: 0.180796
# [363]	valid_0's multi_logloss: 0.180596
# [364]	valid_0's multi_logloss: 0.180943
# [365]	valid_0's multi_logloss: 0.179901
# [366]	valid_0's multi_logloss: 0.179911
# [367]	valid_0's multi_logloss: 0.182158
# [368]	valid_0's multi_logloss: 0.186539
# [369]	valid_0's multi_logloss: 0.195292
# [370]	valid_0's multi_logloss: 0.191838
# [371]	valid_0's multi_logloss: 0.191279
# [372]	valid_0's multi_logloss: 0.188461
# [373]	valid_0's multi_logloss: 0.187269
# [374]	valid_0's multi_logloss: 0.186893
# [375]	valid_0's multi_logloss: 0.18675
# [376]	valid_0's multi_logloss: 0.186325
# [377]	valid_0's multi_logloss: 0.185007
# [378]	valid_0's multi_logloss: 0.1843
# [379]	valid_0's multi_logloss: 0.183658
# [380]	valid_0's multi_logloss: 0.182718
# [381]	valid_0's multi_logloss: 0.182512
# [382]	valid_0's multi_logloss: 0.182569
# [383]	valid_0's multi_logloss: 0.182445
# [384]	valid_0's multi_logloss: 0.181592
# [385]	valid_0's multi_logloss: 0.181439
# [386]	valid_0's multi_logloss: 0.180971
# [387]	valid_0's multi_logloss: 0.180707
# [388]	valid_0's multi_logloss: 0.180547
# [389]	valid_0's multi_logloss: 0.180394
# [390]	valid_0's multi_logloss: 0.180711
# [391]	valid_0's multi_logloss: 0.180591
# [392]	valid_0's multi_logloss: 0.178869
# [393]	valid_0's multi_logloss: 0.183761
# [394]	valid_0's multi_logloss: 0.18359
# [395]	valid_0's multi_logloss: 0.183012
# [396]	valid_0's multi_logloss: 0.180943
# [397]	valid_0's multi_logloss: 0.183087
# [398]	valid_0's multi_logloss: 0.182973
# [399]	valid_0's multi_logloss: 0.182624
# [400]	valid_0's multi_logloss: 0.182762
# [401]	valid_0's multi_logloss: 0.182623
# [402]	valid_0's multi_logloss: 0.182163
# [403]	valid_0's multi_logloss: 0.182066
# [404]	valid_0's multi_logloss: 0.182196
# [405]	valid_0's multi_logloss: 0.181564
# [406]	valid_0's multi_logloss: 0.182482
# [407]	valid_0's multi_logloss: 0.184614
# [408]	valid_0's multi_logloss: 0.184913
# [409]	valid_0's multi_logloss: 0.183673
# [410]	valid_0's multi_logloss: 0.188442
# [411]	valid_0's multi_logloss: 0.187662
# [412]	valid_0's multi_logloss: 0.188282
# [413]	valid_0's multi_logloss: 0.187674
# [414]	valid_0's multi_logloss: 0.186251
# [415]	valid_0's multi_logloss: 0.186082
# [416]	valid_0's multi_logloss: 0.184484
# [417]	valid_0's multi_logloss: 0.184357
# [418]	valid_0's multi_logloss: 0.19379
# [419]	valid_0's multi_logloss: 0.192081
# [420]	valid_0's multi_logloss: 0.18887
# [421]	valid_0's multi_logloss: 0.188702
# [422]	valid_0's multi_logloss: 0.188555
# [423]	valid_0's multi_logloss: 0.186658
# [424]	valid_0's multi_logloss: 0.186536
# [425]	valid_0's multi_logloss: 0.185269
# [426]	valid_0's multi_logloss: 0.186924
# [427]	valid_0's multi_logloss: 0.188444
# [428]	valid_0's multi_logloss: 0.187115
# [429]	valid_0's multi_logloss: 0.186858
# [430]	valid_0's multi_logloss: 0.186533
# [431]	valid_0's multi_logloss: 0.186777
# [432]	valid_0's multi_logloss: 0.186535
# [433]	valid_0's multi_logloss: 0.186406
# [434]	valid_0's multi_logloss: 0.186201
# [435]	valid_0's multi_logloss: 0.186111
# [436]	valid_0's multi_logloss: 0.18601
# [437]	valid_0's multi_logloss: 0.189647
# [438]	valid_0's multi_logloss: 0.186739
# [439]	valid_0's multi_logloss: 0.186003
# [440]	valid_0's multi_logloss: 0.184972
# [441]	valid_0's multi_logloss: 0.184571
# [442]	valid_0's multi_logloss: 0.186595
# [443]	valid_0's multi_logloss: 0.186285
# [444]	valid_0's multi_logloss: 0.185188
# [445]	valid_0's multi_logloss: 0.184272
# [446]	valid_0's multi_logloss: 0.184182
# [447]	valid_0's multi_logloss: 0.191145
# [448]	valid_0's multi_logloss: 0.190164
# [449]	valid_0's multi_logloss: 0.184676
# [450]	valid_0's multi_logloss: 0.184321
# [451]	valid_0's multi_logloss: 0.184114
# [452]	valid_0's multi_logloss: 0.182966
# [453]	valid_0's multi_logloss: 0.199174
# [454]	valid_0's multi_logloss: 0.18983
# [455]	valid_0's multi_logloss: 0.188842
# [456]	valid_0's multi_logloss: 0.189786
# [457]	valid_0's multi_logloss: 0.188956
# [458]	valid_0's multi_logloss: 0.186817
# [459]	valid_0's multi_logloss: 0.18553
# [460]	valid_0's multi_logloss: 0.183746
# [461]	valid_0's multi_logloss: 0.193151
# [462]	valid_0's multi_logloss: 0.190447
# [463]	valid_0's multi_logloss: 0.189103
# [464]	valid_0's multi_logloss: 0.187977
# [465]	valid_0's multi_logloss: 0.185057
# [466]	valid_0's multi_logloss: 0.185395
# [467]	valid_0's multi_logloss: 0.197757
# [468]	valid_0's multi_logloss: 0.194929
# [469]	valid_0's multi_logloss: 0.188569
# [470]	valid_0's multi_logloss: 0.186046
# [471]	valid_0's multi_logloss: 0.184422
# [472]	valid_0's multi_logloss: 0.196318
# [473]	valid_0's multi_logloss: 0.196165
# [474]	valid_0's multi_logloss: 0.195753
# [475]	valid_0's multi_logloss: 0.193122
# [476]	valid_0's multi_logloss: 0.192761
# [477]	valid_0's multi_logloss: 0.199373
# [478]	valid_0's multi_logloss: 0.193201
# [479]	valid_0's multi_logloss: 0.189357
# [480]	valid_0's multi_logloss: 0.188639
# [481]	valid_0's multi_logloss: 0.188716
# [482]	valid_0's multi_logloss: 0.187146
# [483]	valid_0's multi_logloss: 0.186869
# [484]	valid_0's multi_logloss: 0.198042
# [485]	valid_0's multi_logloss: 0.19714
# [486]	valid_0's multi_logloss: 0.196802
# [487]	valid_0's multi_logloss: 0.195472
# [488]	valid_0's multi_logloss: 0.194033
# [489]	valid_0's multi_logloss: 0.193782
# [490]	valid_0's multi_logloss: 0.192327
# [491]	valid_0's multi_logloss: 0.191038
# [492]	valid_0's multi_logloss: 0.19473
# Early stopping, best iteration is:
# [392]	valid_0's multi_logloss: 0.178869

# %%
y_train
# Out:
# array([0, 0, 6, ..., 7, 5, 0])

# %%
submission = pd.read_csv('../input/test.csv')
ids = submission['id'].values
submission.drop('id', inplace=True, axis=1)


x = submission.values
y = model.predict(x)

output = pd.DataFrame({'id': ids, 'target': y})
output.to_csv("submission.csv", index=False)
